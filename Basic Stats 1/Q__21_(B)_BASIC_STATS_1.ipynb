# %%
from scipy import stats
from scipy.stats import norm
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
wcat = pd.read_csv('/content/wc-at.csv')

# %%
sns.distplot(wcat.Waist, label = 'WCAT- WAIST', bins = 10, )
plt.xlabel('Waist');
plt.ylabel('Density');
plt.legend();

# %%
sns.distplot(wcat.AT, label = 'WCAT- ADIPOSE TISSUE', bins = 10, )
plt.xlabel('Adipose Tissue');
plt.ylabel('Density');
plt.legend();
